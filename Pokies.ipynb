# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
###
### THIS FILE FINDS THE TOP WINNINGS PER POKIE IN LATEST MONTH
### WIN/MACHINE AND MACHINE% CALCULATED IN EXCEL IN OCT18 EXAMPLE
### DATA: https://data.qld.gov.au/dataset/total-queensland-club-gaming-machine-data

# %%
df1 = pd.read_csv("20181115_OLGR_LGA-EGM-data.csv")
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-17-78d2619e3dcf> in <module>()
# ----> 1 df1 = pd.read_csv("20181115_OLGR_LGA-EGM-data.csv")
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
# ...

# %%
df1

# %%
df2 = df1[df1['Approved Sites'] > 6]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-10-08ce06557087> in <module>()
# ----> 1 df2 = df1[df1['Approved Sites'] > 6]
#
# NameError: name 'df1' is not defined

# %%
df_monthly = df2[df2['Month Year'] == 'Oct-18']
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-11-777bbfa8072d> in <module>()
# ----> 1 df_monthly = df2[df2['Month Year'] == 'Oct-18']
#
# NameError: name 'df2' is not defined

# %%
df_monthly
# Out:
#      Month Year         LGA Region  Approved Sites  Operational Sites  \
# 30       Oct-18              LOGAN              37               35.0
# 141      Oct-18        MORETON BAY              60               60.0
# 224      Oct-18         WHITSUNDAY              18               16.0
# 235      Oct-18             CAIRNS              40               39.0
# 305      Oct-18            REDLAND              28               27.0
# 306      Oct-18            IPSWICH              34               33.0
# 357      Oct-18     LOCKYER VALLEY              14               14.0
# 471      Oct-18        ROCKHAMPTON              32               30.0
# 543      Oct-18            DOUGLAS               8                8.0
# 813      Oct-18        LIVINGSTONE              12               11.0
# 833      Oct-18              NOOSA              14               14.0
# 1113     Oct-18             MACKAY              40               37.0
# ...

# %%
    df_monthly.sort_values('Win/machine',ascending=False)
# Out:
#      Month Year         LGA Region  Approved Sites  Operational Sites  \
# 30       Oct-18              LOGAN              37               35.0
# 141      Oct-18        MORETON BAY              60               60.0
# 3960     Oct-18           BRISBANE             183              175.0
# 224      Oct-18         WHITSUNDAY              18               16.0
# 235      Oct-18             CAIRNS              40               39.0
# 305      Oct-18            REDLAND              28               27.0
# 306      Oct-18            IPSWICH              34               33.0
# 3539     Oct-18         GOLD COAST             129              124.0
# 357      Oct-18     LOCKYER VALLEY              14               14.0
# 3241     Oct-18         TOWNSVILLE              43               39.0
# 471      Oct-18        ROCKHAMPTON              32               30.0
# 543      Oct-18            DOUGLAS               8                8.0
# ...

# %%
df_monthly.sort_values('Metered Win',ascending=False)
# Out:
#      Month Year         LGA Region  Approved Sites  Operational Sites  \
# 3960     Oct-18           BRISBANE             183              175.0
# 3539     Oct-18         GOLD COAST             129              124.0
# 141      Oct-18        MORETON BAY              60               60.0
# 30       Oct-18              LOGAN              37               35.0
# 4755     Oct-18     SUNSHINE COAST              68               67.0
# 235      Oct-18             CAIRNS              40               39.0
# 3241     Oct-18         TOWNSVILLE              43               39.0
# 306      Oct-18            IPSWICH              34               33.0
# 1113     Oct-18             MACKAY              40               37.0
# 1150     Oct-18          TOOWOOMBA              50               47.0
# 305      Oct-18            REDLAND              28               27.0
# 1881     Oct-18       FRASER COAST              33               33.0
# ...
